# %% [markdown]
# ## Trajectory preprocessing

# %% [markdown]
# We need to make molecules whole and center them
# http://www.gromacs.org/Documentation/Terminology/Periodic_Boundary_Conditions
# http://manual.gromacs.org/documentation/current/onlinehelp/gmx-trjconv.html

# %%
#Reloading funcs if changed
from importlib import reload 
import funcs,config
reload(funcs)
reload(config)


from IPython.display import Markdown, display
from config import folder,descr,pname,scuser
display(Markdown(descr))
# Out:
# # MD simulations of H3-H4, tails truncated
# - AMBER14SB force field
# - 50 mM NaCl
# - box 2nm

# %%
# %%bash
# mkdir -p tmp
# mkdir -p big_data
# #The group here may need to be adjusted if you have other components except protein, e.g. DNA
# gmx trjconv -n GMX_system/index.ndx -f GMX_run/7_prod.xtc -s GMX_run/7_prod.tpr -o tmp/7_prod_1.xtc -pbc whole << !
# !Water_and_ions
# !
# Out:
# Select group for output
# Selected 19: '!Water_and_ions'
#                      :-) GROMACS - gmx trjconv, 2018.3 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar    Aldert van Buuren   Rudi van Drunen     Anton Feenstra
#   Gerrit Groenhof    Aleksei Iupinov   Christoph Junghans   Anca Hamuraru
#  Vincent Hindriksen Dimitrios Karkoulis    Peter Kasson        Jiri Kraus
#   Carsten Kutzner      Per Larsson      Justin A. Lemkul    Viveca Lindahl
#   Magnus Lundborg   Pieter Meulenhoff    Erik Marklund      Teemu Murtola
#     Szilard Pall       Sander Pronk      Roland Schulz     Alexey Shvetsov
#    Michael Shirts     Alfons Sijbers     Peter Tieleman    Teemu Virolainen
#  Christian Wennberg    Maarten Wolf
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2017, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx trjconv, version 2018.3
# Executable:   /opt/miniconda3/envs/moldyn/bin/gmx
# Data prefix:  /opt/miniconda3/envs/moldyn
# Working dir:  /home/_shared/_projects/gmx_template
# Command line:
#   gmx trjconv -n GMX_system/index.ndx -f GMX_run/7_prod.xtc -s GMX_run/7_prod.tpr -o tmp/7_prod_1.xtc -pbc whole
#
# Will write xtc: Compressed trajectory (portable xdr format): xtc
# Reading file GMX_run/7_prod.tpr, VERSION 2018.3 (single precision)
# Reading file GMX_run/7_prod.tpr, VERSION 2018.3 (single precision)
# Group     0 (         System) has 85975 elements
# Group     1 (        Protein) has  2867 elements
# Group     2 (      Protein-H) has  1394 elements
# Group     3 (        C-alpha) has   172 elements
# Group     4 (       Backbone) has   518 elements
# Group     5 (      MainChain) has   694 elements
# Group     6 (   MainChain+Cb) has   855 elements
# Group     7 (    MainChain+H) has   863 elements
# Group     8 (      SideChain) has  2004 elements
# Group     9 (    SideChain-H) has   700 elements
# Group    10 (    Prot-Masses) has  2867 elements
# Group    11 (    non-Protein) has 83108 elements
# Group    12 (          Water) has 82944 elements
# Group    13 (            SOL) has 82944 elements
# Group    14 (      non-Water) has  3031 elements
# Group    15 (            Ion) has   164 elements
# Group    16 (             NA) has    75 elements
# Group    17 (             CL) has    89 elements
# Group    18 ( Water_and_ions) has 83108 elements
# Group    19 (!Water_and_ions) has  2867 elements
# Reading frame       0 time    0.000
# Precision of GMX_run/7_prod.xtc is 0.001 (nm)
# Using output precision of 0.001 (nm)
#
# Back Off! I just backed up tmp/7_prod_1.xtc to tmp/#7_prod_1.xtc.5#
# Last frame       1000 time 1000000.000
#
#
# GROMACS reminds you: "This type of advanced sampling techniques... which are not so advanced, really." (Viveca Lindahl, on AWH, at her thesis defense.)

# %%
# %%bash --out out
# gmx trjconv -n GMX_system/index.ndx -f tmp/7_prod_1.xtc -s GMX_run/7_prod.tpr -o tmp/7_prod_2.xtc -pbc cluster << !
# !Water_and_ions
# !Water_and_ions
# !
# Out:
#                      :-) GROMACS - gmx trjconv, 2018.3 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar    Aldert van Buuren   Rudi van Drunen     Anton Feenstra
#   Gerrit Groenhof    Aleksei Iupinov   Christoph Junghans   Anca Hamuraru
#  Vincent Hindriksen Dimitrios Karkoulis    Peter Kasson        Jiri Kraus
#   Carsten Kutzner      Per Larsson      Justin A. Lemkul    Viveca Lindahl
#   Magnus Lundborg   Pieter Meulenhoff    Erik Marklund      Teemu Murtola
#     Szilard Pall       Sander Pronk      Roland Schulz     Alexey Shvetsov
#    Michael Shirts     Alfons Sijbers     Peter Tieleman    Teemu Virolainen
#  Christian Wennberg    Maarten Wolf
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2017, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx trjconv, version 2018.3
# Executable:   /opt/miniconda3/envs/moldyn/bin/gmx
# Data prefix:  /opt/miniconda3/envs/moldyn
# Working dir:  /home/_shared/_projects/gmx_template
# Command line:
#   gmx trjconv -n GMX_system/index.ndx -f tmp/7_prod_1.xtc -s GMX_run/7_prod.tpr -o tmp/7_prod_2.xtc -pbc cluster
#
# Will write xtc: Compressed trajectory (portable xdr format): xtc
# Reading file GMX_run/7_prod.tpr, VERSION 2018.3 (single precision)
# Reading file GMX_run/7_prod.tpr, VERSION 2018.3 (single precision)
# Group     0 (         System) has 85975 elements
# Group     1 (        Protein) has  2867 elements
# Group     2 (      Protein-H) has  1394 elements
# Group     3 (        C-alpha) has   172 elements
# Group     4 (       Backbone) has   518 elements
# Group     5 (      MainChain) has   694 elements
# Group     6 (   MainChain+Cb) has   855 elements
# Group     7 (    MainChain+H) has   863 elements
# Group     8 (      SideChain) has  2004 elements
# Group     9 (    SideChain-H) has   700 elements
# Group    10 (    Prot-Masses) has  2867 elements
# Group    11 (    non-Protein) has 83108 elements
# Group    12 (          Water) has 82944 elements
# Group    13 (            SOL) has 82944 elements
# Group    14 (      non-Water) has  3031 elements
# Group    15 (            Ion) has   164 elements
# Group    16 (             NA) has    75 elements
# Group    17 (             CL) has    89 elements
# Group    18 ( Water_and_ions) has 83108 elements
# Group    19 (!Water_and_ions) has  2867 elements
# Select a group: Group     0 (         System) has 85975 elements
# Group     1 (        Protein) has  2867 elements
# Group     2 (      Protein-H) has  1394 elements
# Group     3 (        C-alpha) has   172 elements
# Group     4 (       Backbone) has   518 elements
# Group     5 (      MainChain) has   694 elements
# Group     6 (   MainChain+Cb) has   855 elements
# Group     7 (    MainChain+H) has   863 elements
# Group     8 (      SideChain) has  2004 elements
# Group     9 (    SideChain-H) has   700 elements
# Group    10 (    Prot-Masses) has  2867 elements
# Group    11 (    non-Protein) has 83108 elements
# Group    12 (          Water) has 82944 elements
# Group    13 (            SOL) has 82944 elements
# Group    14 (      non-Water) has  3031 elements
# Group    15 (            Ion) has   164 elements
# Group    16 (             NA) has    75 elements
# Group    17 (             CL) has    89 elements
# Group    18 ( Water_and_ions) has 83108 elements
# Group    19 (!Water_and_ions) has  2867 elements
# Reading frame       0 time    0.000
# Precision of tmp/7_prod_1.xtc is 0.001 (nm)
# Using output precision of 0.001 (nm)
#
# Back Off! I just backed up tmp/7_prod_2.xtc to tmp/#7_prod_2.xtc.3#
# Last frame       1000 time 1000000.000
#
#
# GROMACS reminds you: "Kissing You is Like Kissing Gravel" (Throwing Muses)

# %%
# %%bash
# gmx trjconv  -f tmp/7_prod_2.xtc -s GMX_system/sys_ref.pdb -o big_data/sys_md.xtc -fit rot+trans << !
# System
# System
# !
# Out:
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary.
#
# Select group for least squares fit
# Selected 0: 'System'
# Select group for output
# Selected 0: 'System'
#                      :-) GROMACS - gmx trjconv, 2018.3 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar    Aldert van Buuren   Rudi van Drunen     Anton Feenstra
#   Gerrit Groenhof    Aleksei Iupinov   Christoph Junghans   Anca Hamuraru
#  Vincent Hindriksen Dimitrios Karkoulis    Peter Kasson        Jiri Kraus
#   Carsten Kutzner      Per Larsson      Justin A. Lemkul    Viveca Lindahl
#   Magnus Lundborg   Pieter Meulenhoff    Erik Marklund      Teemu Murtola
#     Szilard Pall       Sander Pronk      Roland Schulz     Alexey Shvetsov
#    Michael Shirts     Alfons Sijbers     Peter Tieleman    Teemu Virolainen
#  Christian Wennberg    Maarten Wolf
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2017, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx trjconv, version 2018.3
# Executable:   /opt/miniconda3/envs/moldyn/bin/gmx
# Data prefix:  /opt/miniconda3/envs/moldyn
# Working dir:  /home/_shared/_projects/gmx_template
# Command line:
#   gmx trjconv -f tmp/7_prod_2.xtc -s GMX_system/sys_ref.pdb -o big_data/sys_md.xtc -fit rot+trans
#
# Will write xtc: Compressed trajectory (portable xdr format): xtc
#
# WARNING: If there are molecules in the input trajectory file
#          that are broken across periodic boundaries, they
#          cannot be made whole (or treated as whole) without
#          you providing a run input file.
#
# Group     0 (         System) has  3392 elements
# Group     1 (        Protein) has  2867 elements
# Group     2 (      Protein-H) has  1394 elements
# Group     3 (        C-alpha) has   172 elements
# Group     4 (       Backbone) has   518 elements
# Group     5 (      MainChain) has   694 elements
# Group     6 (   MainChain+Cb) has   855 elements
# Group     7 (    MainChain+H) has   863 elements
# Group     8 (      SideChain) has  2004 elements
# Group     9 (    SideChain-H) has   700 elements
# Group    10 (    Prot-Masses) has  2867 elements
# Group    11 (    non-Protein) has   525 elements
# Group    12 (          Water) has   525 elements
# Group    13 (            SOL) has   525 elements
# Group    14 (      non-Water) has  2867 elements
# Select a group: Group     0 (         System) has  3392 elements
# Group     1 (        Protein) has  2867 elements
# Group     2 (      Protein-H) has  1394 elements
# Group     3 (        C-alpha) has   172 elements
# Group     4 (       Backbone) has   518 elements
# Group     5 (      MainChain) has   694 elements
# Group     6 (   MainChain+Cb) has   855 elements
# Group     7 (    MainChain+H) has   863 elements
# Group     8 (      SideChain) has  2004 elements
# Group     9 (    SideChain-H) has   700 elements
# Group    10 (    Prot-Masses) has  2867 elements
# Group    11 (    non-Protein) has   525 elements
# Group    12 (          Water) has   525 elements
# Group    13 (            SOL) has   525 elements
# Group    14 (      non-Water) has  2867 elements
# Reading frame       0 time    0.000
# Precision of tmp/7_prod_2.xtc is 0.001 (nm)
# Using output precision of 0.001 (nm)
#
# -------------------------------------------------------
# Program:     gmx trjconv, version 2018.3
# Source file: src/gromacs/gmxana/gmx_trjconv.cpp (line 1350)
#
# Fatal error:
# Index[2867] 2868 is larger than the number of atoms in the
# trajectory file (2867). There is a mismatch in the contents
# of your -f, -s and/or -n files.
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-12-b95635db8fe6> in <module>
# ----> 1 get_ipython().run_cell_magic('bash', '', 'gmx trjconv  -f tmp/7_prod_2.xtc -s GMX_system/sys_ref.pdb -o big_data/sys_md.xtc -fit rot+trans << !\nSystem\nSystem\n!\n')
#
# /opt/miniconda3/envs/moldyn/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2321             magic_arg_s = self.var_expand(line, stack_depth)
#    2322             with self.builtin_trap:
# -> 2323                 result = fn(magic_arg_s, cell)
#    2324             return result
#    2325
#
# /opt/miniconda3/envs/moldyn/lib/python3.7/site-packages/IPython/core/magics/script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# <decorator-gen-109> in shebang(self, line, cell)
#
# /opt/miniconda3/envs/moldyn/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /opt/miniconda3/envs/moldyn/lib/python3.7/site-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'gmx trjconv  -f tmp/7_prod_2.xtc -s GMX_system/sys_ref.pdb -o big_data/sys_md.xtc -fit rot+trans << !\nSystem\nSystem\n!\n'' returned non-zero exit status 1.
